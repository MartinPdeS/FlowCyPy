# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def generate_data(
    x,
    amplitudes=[1.0, 2.0, 0.5, 0.0],  # 0.0 amplitude means "unused" peak
    centers=[0.0, 2.0, -2.0, 5.0],
    widths=[0.5, 0.7, 0.3, 1.0],
    noise_std=0.05
):
    """
    Create synthetic data as a sum of Gaussians, possibly with some noise.
    If an amplitude is zero, that effectively removes that Gaussian peak.
    """
    y = np.zeros_like(x, dtype=np.float32)
    for amp, c, w in zip(amplitudes, centers, widths):
        if amp != 0.0:
            y += amp * np.exp(-0.5 * ((x - c) / w) ** 2)
    # Add Gaussian noise to simulate measurement
    noise = np.random.normal(0.0, noise_std, size=x.shape).astype(np.float32)
    return y + noise

# %%
# Define an x-axis for our synthetic data
x_data = np.linspace(-5, 10, 300).astype(np.float32)

# True parameters for synthetic data (adjust as needed)
true_amplitudes = [1.5, 2.7, 0.8, 1.0]
true_centers    = [ 0.0,  2.2, -2.0, 6.5]
true_widths     = [ 0.5,  0.8,  0.4, 0.9]

# Generate synthetic signal
y_data = generate_data(
    x_data,
    amplitudes=true_amplitudes,
    centers=true_centers,
    widths=true_widths,
    noise_std=0.05
)

# %%
initial_amplitudes = tf.Variable([1.0, 1.0, 1.0, 1.0], dtype=tf.float32)
initial_centers    = tf.Variable([0.0, 1.0, -1.0, 4.0], dtype=tf.float32)
initial_widths     = tf.Variable([0.5, 0.5, 0.5, 0.5], dtype=tf.float32)

# %%
def multi_gaussian_model(x):
    """
    Returns the sum of up to 4 Gaussians using the current
    trainable TF variables.
    """
    gaussians = []
    for i in range(4):
        amp = initial_amplitudes[i]
        cen = initial_centers[i]
        wid = tf.math.abs(initial_widths[i])  # enforce positivity
        peak = amp * tf.exp(-0.5 * ((x - cen) / wid) ** 2)
        gaussians.append(peak)
    return tf.reduce_sum(gaussians, axis=0)

def loss_fn(x, y):
    y_pred = multi_gaussian_model(x)
    return tf.reduce_mean((y - y_pred) ** 2)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

loss_history = []

# Convert data to TF tensors (for convenience)
x_tf = tf.constant(x_data, dtype=tf.float32)
y_tf = tf.constant(y_data, dtype=tf.float32)

# Number of epochs for demonstration
epochs = 3000

for epoch in range(epochs):
    with tf.GradientTape() as tape:
        current_loss = loss_fn(x_tf, y_tf)
        
    grads = tape.gradient(current_loss, [initial_amplitudes, initial_centers, initial_widths])
    optimizer.apply_gradients(zip(grads, [initial_amplitudes, initial_centers, initial_widths]))
    
    loss_history.append(current_loss.numpy())
    
    # (Optional) Print progress occasionally
    if epoch % 500 == 0:
        print(f"Epoch {epoch:5d} | Loss = {current_loss.numpy():.6f}")

###############################################################################
# 6. Evaluate and Print Results
###############################################################################
final_loss = loss_fn(x_tf, y_tf).numpy()
print("\nTraining finished.")
print("Final Loss =", final_loss)

print("\nRetrieved Parameters:")
print("Amplitudes:", initial_amplitudes.numpy())
print("Centers:   ", initial_centers.numpy())
print("Widths:    ", initial_widths.numpy())

# Compare with the true parameters
print("\nTrue Parameters:")
print("Amplitudes:", true_amplitudes)
print("Centers:   ", true_centers)
print("Widths:    ", true_widths)
# Out:
# Epoch     0 | Loss = 0.722875
# Epoch   500 | Loss = 0.054754
# Epoch  1000 | Loss = 0.040099
# Epoch  1500 | Loss = 0.034196
# Epoch  2000 | Loss = 0.002524
# Epoch  2500 | Loss = 0.002524
#
# Training finished.
# Final Loss = 0.0025240448
#
# Retrieved Parameters:
# Amplitudes: [1.5032027  2.6910422  0.79126525 0.9827781 ]
# Centers:    [-3.2528487e-03  2.1897035e+00 -1.9851452e+00  6.5060668e+00]
# Widths:     [0.491903   0.8125394  0.39241838 0.90456986]
#
# True Parameters:
# Amplitudes: [1.5, 2.7, 0.8, 1.0]
# Centers:    [0.0, 2.2, -2.0, 6.5]
# Widths:     [0.5, 0.8, 0.4, 0.9]

# %%
y_fit = multi_gaussian_model(x_tf).numpy()

plt.figure(figsize=(8, 5))
plt.scatter(x_data, y_data, s=10, alpha=0.5, label='Noisy Data')
plt.plot(x_data, y_fit, 'r-', label='Fitted Sum of Gaussians', linewidth=2)

# Optionally, you can also plot each individual peak
for i in range(4):
    amp = initial_amplitudes[i].numpy()
    cen = initial_centers[i].numpy()
    wid = abs(initial_widths[i].numpy())
    single_peak = amp * np.exp(-0.5 * ((x_data - cen) / wid) ** 2)
    plt.plot(x_data, single_peak, '--', label=f'Peak {i+1}')

plt.title('Fitting Up To Four Gaussian Peaks with TensorFlow')
plt.xlabel('x')
plt.ylabel('Signal')
plt.legend()
plt.show()

# Plot training loss
plt.figure(figsize=(8,5))
plt.plot(loss_history, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

###############################################################################
# 1. Create a Synthetic Dataset of 1D Signals (sum of up to 4 Gaussians)
###############################################################################

def generate_random_signal(n_points=100, max_peaks=4, noise_std=0.02):
    """
    Generate a single 1D signal of length `n_points` containing up to `max_peaks` Gaussians
    with random amplitudes, centers, and widths. We add Gaussian noise as well.
    """
    x = np.linspace(-5, 5, n_points)  # or any domain you like
    y = np.zeros_like(x)
    
    n_peaks = np.random.randint(1, max_peaks+1)  # 1 to max_peaks
    
    for _ in range(n_peaks):
        amp = np.random.uniform(0.5, 2.0)
        cen = np.random.uniform(-4.0, 4.0)
        wid = np.random.uniform(0.2, 1.0)
        y += amp * np.exp(-0.5 * ((x - cen)/wid)**2)
    
    # Add noise
    y += np.random.normal(0.0, noise_std, size=n_points)
    
    return x, y

# Generate a dataset of multiple signals
n_samples = 2000
n_points = 100
X_data = []
for _ in range(n_samples):
    x_axis, y_signal = generate_random_signal(n_points=n_points, max_peaks=4, noise_std=0.01)
    X_data.append(y_signal)

X_data = np.array(X_data, dtype=np.float32)  # shape: (n_samples, n_points)
# We'll assume all signals share the same x-axis for this example:
x_positions = x_axis  # shape (n_points,)

# We now have an input dataset X_data of shape (2000, 100).

# Train/test split
split_idx = int(0.8 * n_samples)
X_train = X_data[:split_idx]
X_test  = X_data[split_idx:]

print("X_train shape:", X_train.shape)  # (1600, 100)
print("X_test shape :", X_test.shape)   # (400, 100)


###############################################################################
# 2. Build a Custom "Physics-Informed" Decoder Layer:
#    This layer takes 12 parameters => reconstructs sum of 4 Gaussians of length N.
###############################################################################

class GaussianDecoder(tf.keras.layers.Layer):
    """
    Takes an input of shape (batch_size, 12):
       [a1,a2,a3,a4, c1,c2,c3,c4, w1,w2,w3,w4]
    and reconstructs a signal of shape (batch_size, N) by summing 4 Gaussians.
    """
    def __init__(self, x_positions, num_peaks=4, **kwargs):
        super().__init__(**kwargs)
        self.x_positions = tf.constant(x_positions, dtype=tf.float32)  # shape (N,)
        self.num_peaks   = num_peaks
        self.N           = x_positions.shape[0]

    def call(self, inputs):
        """
        inputs shape: (batch_size, 12)
        returns shape: (batch_size, N)
        """
        batch_size = tf.shape(inputs)[0]  # dynamic batch size

        # 1) Parse the 12 parameters
        amps    = inputs[:, 0:self.num_peaks]                  # (batch_size, 4)
        centers = inputs[:, self.num_peaks:2*self.num_peaks]   # (batch_size, 4)
        raw_w   = inputs[:, 2*self.num_peaks:3*self.num_peaks] # (batch_size, 4)

        # 2) Force widths > 0
        widths  = tf.nn.softplus(raw_w) + 1e-6                 # (batch_size, 4)

        # 3) Broadcast so that final shape is (batch_size, 4, N)
        # x_positions: (N,) -> expand to (1, N)
        x_positions_2d = tf.reshape(self.x_positions, [1, self.N])  # (1, N)
        # tile across batch and peak dimension => (batch_size, 4, N)
        x_tiled = tf.tile(
            tf.expand_dims(x_positions_2d, axis=1),  # shape (1, 1, N)
            [batch_size, self.num_peaks, 1]          # => (batch_size, 4, N)
        )

        # Similarly expand amps, centers, widths => (batch_size, 4, 1)
        amps    = tf.expand_dims(amps,    axis=-1)  # => (batch_size, 4, 1)
        centers = tf.expand_dims(centers, axis=-1)  # => (batch_size, 4, 1)
        widths  = tf.expand_dims(widths,  axis=-1)  # => (batch_size, 4, 1)

        # 4) Compute Gaussians => shape (batch_size, 4, N)
        gaussians = amps * tf.exp(-0.5 * tf.square((x_tiled - centers) / widths))

        # 5) Sum over the '4' axis => shape (batch_size, N)
        output = tf.reduce_sum(gaussians, axis=1)
        return output



###############################################################################
# 3. Build the Overall Model:
#    - Input: the raw 1D signal (shape (N,))
#    - Hidden "encoder" layers => produce 12 parameters
#    - "GaussianDecoder" => reconstruct the signal of shape (N,)
###############################################################################

def build_physics_informed_autoencoder(n_points=100, num_peaks=4):
    """
    Build a model that:
      Input shape: (n_points,)
      Output shape: (n_points,)
      Internally: parameter layer of shape (12,) => GaussianDecoder => (n_points,)
    """
    inputs = layers.Input(shape=(n_points,), name="signal_input")
    
    # Example "encoder" part. You can add more layers if needed.
    x = layers.Dense(64, activation='relu')(inputs)
    x = layers.Dense(64, activation='relu')(x)
    
    # Output 3*num_peaks params: amplitude, center, width
    param_output = layers.Dense(3 * num_peaks, activation='linear', name="param_output")(x)
    
    # Physics-based decoder to reconstruct the signal from the 12 params
    reconstructed_signal = GaussianDecoder(
        x_positions=x_positions, 
        num_peaks=num_peaks,
        name="gaussian_decoder"
    )(param_output)
    
    # Our final model
    model = models.Model(inputs=inputs, outputs=reconstructed_signal, name="Gaussian_AE")
    return model

# Build it
model = build_physics_informed_autoencoder(n_points=n_points, num_peaks=4)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='mean_squared_error'
)

model.summary()

###############################################################################
# 4. Train the Model WITHOUT a Manual Loop (model.fit)
###############################################################################
# We'll do a standard autoencoder approach: X -> model -> X_reconstructed
# so we use X_train as both inputs and targets.

history = model.fit(
    X_train,
    X_train,
    validation_data=(X_test, X_test),
    epochs=150,
    batch_size=32,
    verbose=1
)

###############################################################################
# 5. Evaluate & Inspect Results
###############################################################################
print("\nTraining completed.")
print("Final training loss:", history.history["loss"][-1])
print("Final validation loss:", history.history["val_loss"][-1])

# Let's pick a random test sample and see how well the model reconstructs it
idx = np.random.randint(0, X_test.shape[0])
test_signal = X_test[idx]          # shape (100,)
test_signal = test_signal[np.newaxis, :]  # shape (1, 100) for predict

reconstructed = model.predict(test_signal)[0]  # shape (100,)

# Compare
plt.figure(figsize=(8,4))
plt.plot(x_positions, test_signal[0], 'bo-', markersize=3, label='Original Signal')
plt.plot(x_positions, reconstructed, 'r-', label='Reconstructed (4 Gaussians)', linewidth=2)
plt.title("Test Signal vs. Model Reconstruction")
plt.xlabel("x")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

###############################################################################
# 6. Retrieve Fitted Parameters for a Given Signal
###############################################################################
# If you want to retrieve the 12 parameters for a given signal, create a sub-model
# that stops at the "param_output" layer:

encoder = models.Model(
    inputs=model.input,
    outputs=model.get_layer("param_output").output
)

params = encoder.predict(test_signal)  # shape (1, 12)
params = params[0]                    # shape (12,)

amps    = params[:4]
centers = params[4:8]
widths  = params[8:12]
widths  = tf.nn.softplus(widths).numpy()  # ensure positivity

print("\nRetrieved Parameters for that sample:")
print("Amplitudes:", amps)
print("Centers:   ", centers)
print("Widths:    ", widths)
# Out:
# X_train shape: (1600, 100)
# X_test shape : (400, 100)
# Model: "Gaussian_AE"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ signal_input (InputLayer)       │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         6,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ param_output (Dense)            │ (None, 12)             │           780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_decoder                │ (None, 100)            │             0 │
# │ (GaussianDecoder)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,404 (44.55 KB)
#  Trainable params: 11,404 (44.55 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5498 - val_loss: 0.2079
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.1867 - val_loss: 0.1636
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.1541 - val_loss: 0.1497
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.1392 - val_loss: 0.1314
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.1245 - val_loss: 0.1177
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.1176 - val_loss: 0.1082
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.1017 - val_loss: 0.1022
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0935 - val_loss: 0.1046
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.0861 - val_loss: 0.0886
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.0782 - val_loss: 0.0859
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.0757 - val_loss: 0.0762
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.0658 - val_loss: 0.0795
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.0626 - val_loss: 0.0662
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.0610 - val_loss: 0.0657
# Epoch 15/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.0599 - val_loss: 0.0642
# Epoch 16/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.0524 - val_loss: 0.0589
# Epoch 17/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0531 - val_loss: 0.0511
# Epoch 18/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.0461 - val_loss: 0.0515
# Epoch 19/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.0433 - val_loss: 0.0587
# Epoch 20/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.0417 - val_loss: 0.0460
# Epoch 21/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 0.0401 - val_loss: 0.0451
# Epoch 22/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.0369 - val_loss: 0.0463
# Epoch 23/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.0375 - val_loss: 0.0468
# Epoch 24/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - loss: 0.0377 - val_loss: 0.0453
# Epoch 25/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 0.0548 - val_loss: 0.0450
# Epoch 26/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.0368 - val_loss: 0.0404
# Epoch 27/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 0.0346 - val_loss: 0.0453
# Epoch 28/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - loss: 0.0329 - val_loss: 0.0382
# Epoch 29/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.0302 - val_loss: 0.0397
# Epoch 30/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.0302 - val_loss: 0.0396
# Epoch 31/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.0293 - val_loss: 0.0379
# Epoch 32/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.0304 - val_loss: 0.0380
# Epoch 33/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0305 - val_loss: 0.0388
# Epoch 34/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.0320 - val_loss: 0.0388
# Epoch 35/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.0345 - val_loss: 0.0402
# Epoch 36/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0292 - val_loss: 0.0376
# Epoch 37/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.0262 - val_loss: 0.0368
# Epoch 38/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.0287 - val_loss: 0.0337
# Epoch 39/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - loss: 0.0273 - val_loss: 0.0339
# Epoch 40/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.0251 - val_loss: 0.0363
# Epoch 41/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.0267 - val_loss: 0.0315
# Epoch 42/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.0255 - val_loss: 0.0316
# Epoch 43/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.0257 - val_loss: 0.0338
# Epoch 44/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.0248 - val_loss: 0.0328
# Epoch 45/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.0245 - val_loss: 0.0305
# Epoch 46/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.0248 - val_loss: 0.0317
# Epoch 47/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.0252 - val_loss: 0.0328
# Epoch 48/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.0243 - val_loss: 0.0332
# Epoch 49/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.0232 - val_loss: 0.0282
# Epoch 50/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.0215 - val_loss: 0.0275
# Epoch 51/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.0208 - val_loss: 0.0284
# Epoch 52/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.0238 - val_loss: 0.0283
# Epoch 53/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.0228 - val_loss: 0.0409
# Epoch 54/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.0269 - val_loss: 0.0283
# Epoch 55/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.0236 - val_loss: 0.0266
# Epoch 56/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0233 - val_loss: 0.0340
# Epoch 57/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.0259 - val_loss: 0.0260
# Epoch 58/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.0264 - val_loss: 0.0269
# Epoch 59/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.0183 - val_loss: 0.0281
# Epoch 60/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.0191 - val_loss: 0.0252
# Epoch 61/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.0185 - val_loss: 0.0232
# Epoch 62/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.0173 - val_loss: 0.0235
# Epoch 63/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.0171 - val_loss: 0.0231
# Epoch 64/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.0170 - val_loss: 0.0229
# Epoch 65/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.0168 - val_loss: 0.0224
# Epoch 66/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.0157 - val_loss: 0.0217
# Epoch 67/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.0170 - val_loss: 0.0217
# Epoch 68/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.0160 - val_loss: 0.0220
# Epoch 69/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.0165 - val_loss: 0.0226
# Epoch 70/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.0163 - val_loss: 0.0217
# Epoch 71/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - loss: 0.0187 - val_loss: 0.0237
# Epoch 72/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.0176 - val_loss: 0.0217
# Epoch 73/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.0163 - val_loss: 0.0216
# Epoch 74/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - loss: 0.0172 - val_loss: 0.0213
# Epoch 75/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - loss: 0.0195 - val_loss: 0.0218
# Epoch 76/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.0158 - val_loss: 0.0214
# Epoch 77/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0160 - val_loss: 0.0210
# Epoch 78/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 0.0157 - val_loss: 0.0195
# Epoch 79/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.0144 - val_loss: 0.0213
# Epoch 80/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.0144 - val_loss: 0.0204
# Epoch 81/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.0162 - val_loss: 0.0217
# Epoch 82/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.0160 - val_loss: 0.0206
# Epoch 83/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.0151 - val_loss: 0.0199
# Epoch 84/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.0137 - val_loss: 0.0198
# Epoch 85/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0138 - val_loss: 0.0198
# Epoch 86/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.0140 - val_loss: 0.0200
# Epoch 87/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.0129 - val_loss: 0.0204
# Epoch 88/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.0134 - val_loss: 0.0196
# Epoch 89/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.0133 - val_loss: 0.0202
# Epoch 90/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.0158 - val_loss: 0.0187
# Epoch 91/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.0134 - val_loss: 0.0190
# Epoch 92/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.0138 - val_loss: 0.0227
# Epoch 93/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.0142 - val_loss: 0.0204
# Epoch 94/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - val_loss: 0.0195
# Epoch 95/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.0125 - val_loss: 0.0191
# Epoch 96/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.0129 - val_loss: 0.0179
# Epoch 97/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0160 - val_loss: 0.0202
# Epoch 98/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.0133 - val_loss: 0.0211
# Epoch 99/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0135 - val_loss: 0.0193
# Epoch 100/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.0140 - val_loss: 0.0189
# Epoch 101/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.0140 - val_loss: 0.0203
# Epoch 102/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.0136 - val_loss: 0.0195
# Epoch 103/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.0128 - val_loss: 0.0176
# Epoch 104/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.0124 - val_loss: 0.0193
# Epoch 105/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.0125 - val_loss: 0.0182
# Epoch 106/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.0122 - val_loss: 0.0195
# Epoch 107/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0134 - val_loss: 0.0201
# Epoch 108/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.0144 - val_loss: 0.0252
# Epoch 109/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.0165 - val_loss: 0.0194
# Epoch 110/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.0136 - val_loss: 0.0195
# Epoch 111/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.0124 - val_loss: 0.0173
# Epoch 112/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.0125 - val_loss: 0.0198
# Epoch 113/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.0126 - val_loss: 0.0178
# Epoch 114/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.0128 - val_loss: 0.0172
# Epoch 115/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.0113 - val_loss: 0.0164
# Epoch 116/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - val_loss: 0.0177
# Epoch 117/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.0117 - val_loss: 0.0163
# Epoch 118/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.0114 - val_loss: 0.0181
# Epoch 119/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.0112 - val_loss: 0.0165
# Epoch 120/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.0127 - val_loss: 0.0199
# Epoch 121/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.0124 - val_loss: 0.0185
# Epoch 122/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.0132 - val_loss: 0.0181
# Epoch 123/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.0128 - val_loss: 0.0175
# Epoch 124/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.0114 - val_loss: 0.0173
# Epoch 125/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.0109 - val_loss: 0.0192
# Epoch 126/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.0118 - val_loss: 0.0179
# Epoch 127/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.0124 - val_loss: 0.0174
# Epoch 128/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.0116 - val_loss: 0.0204
# Epoch 129/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.0147 - val_loss: 0.0172
# Epoch 130/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0112 - val_loss: 0.0168
# Epoch 131/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.0111 - val_loss: 0.0159
# Epoch 132/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.0112 - val_loss: 0.0176
# Epoch 133/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - val_loss: 0.0177
# Epoch 134/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.0121 - val_loss: 0.0187
# Epoch 135/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.0119 - val_loss: 0.0163
# Epoch 136/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.0118 - val_loss: 0.0172
# Epoch 137/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.0107 - val_loss: 0.0187
# Epoch 138/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.0127 - val_loss: 0.0194
# Epoch 139/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.0124 - val_loss: 0.0161
# Epoch 140/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.0107 - val_loss: 0.0160
# Epoch 141/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.0108 - val_loss: 0.0157
# Epoch 142/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.0105 - val_loss: 0.0169
# Epoch 143/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.0106 - val_loss: 0.0171
# Epoch 144/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.0098 - val_loss: 0.0175
# Epoch 145/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.0106 - val_loss: 0.0168
# Epoch 146/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.0105 - val_loss: 0.0166
# Epoch 147/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.0101 - val_loss: 0.0154
# Epoch 148/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.0113 - val_loss: 0.0174
# Epoch 149/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - val_loss: 0.0179
# Epoch 150/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.0117 - val_loss: 0.0172
#
# Training completed.
# Final training loss: 0.011719166301190853
# Final validation loss: 0.017175035551190376
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x306efb600> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x305e08d60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Retrieved Parameters for that sample:
# Amplitudes: [1.5595393  0.20971978 0.04278668 1.7320307 ]
# Centers:    [ 0.791389   -0.63047856 -1.3855305   2.4813924 ]
# Widths:     [0.79646367 0.33426148 0.2888037  0.9130135 ]
